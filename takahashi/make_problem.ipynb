# %%
import numpy as np
import random
for i in range(10):
    print("入札者:10")
    print(f"財の種類:{random.randint(10, 50)}")
    print("-" * 20)
# Out:
# 入札者:10
# 財の種類:13
# --------------------
# 入札者:10
# 財の種類:39
# --------------------
# 入札者:10
# 財の種類:50
# --------------------
# 入札者:10
# 財の種類:38
# --------------------
# 入札者:10
# 財の種類:28
# --------------------
# 入札者:10
# 財の種類:30
# --------------------
# 入札者:10
# 財の種類:29
# --------------------
# 入札者:10
# 財の種類:23
# --------------------
# 入札者:10
# 財の種類:42
# --------------------
# 入札者:10
# 財の種類:22
# --------------------

# %%
print("[")
for i in range(10):
    arr = np.random.randint(10, 51, size=10)
    print(f"{arr},")
print("]")
