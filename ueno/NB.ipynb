# %%
from typing import List, Dict
import os
import pandas as pd

class NB:
    # Number of Categories
    NC = 2
    # Number of Variables
    NV = 0
    # Leaning Data
    N = 0
    LD = pd.DataFrame()
    # Test Data
    TD = pd.DataFrame()
    # 頻度表
    # N_{X_0=c}の格納先．ft_c[0]=N_{X_0=0}, ft_c[1] = N_{X_0=1}となる(X_0は目的変数を表す)．
    ft_c = []
    # N_{X_i=k,X_0=c}の格納先．例えば，ft_ic[0][0]=N_{X_i=0,X_0=0}, ft_ic[1][0]=N_{X_i=1,X_0=0}となる．
    ft_ic = []

    def __init__(self):
        # データセット入力
        dataset = "spam"
        print("Dataset: "+dataset)
        # データ読み込み
        self.readData(f"data/{dataset}")
        print(f"Number of Test Data: {len(self.TD)}")
        print(f"Number of Learning Data: {len(self.LD)}")
        print(f"Number of Variables: {self.NV}")
        # 頻度表の初期化
        self.ft_c = [0 for _ in range(self.NC)]
        self.ft_ic = [[[0 for _ in range(self.NC)] for _ in range(self.NC)]
                       for _ in range(self.NV - 1)]
        # 頻度表の作成
        self.setFrequencyTable()
        col_to_idx = {name: idx for idx, name in enumerate(self.LD.columns)}
        print("Frequency Table has been set.")
        print("="*50)
        print(f"ft_c[0]:{self.ft_c[0]}, ft_c[1]:{self.ft_c[1]}")
        print(f"true : {len(self.LD[self.LD['CLASS(spam)'] == 0])}, {len(self.LD[self.LD['CLASS(spam)'] == 1])}")
        print("="*50)
        print(f"ft_ic['i'][0][0]:{self.ft_ic[col_to_idx['i']][0][0]}, ft_ic['i'][0][1]:{self.ft_ic[col_to_idx['i']][0][1]}")
        print(f"true : {len(self.LD[(self.LD['i'] == 0) & (self.LD['CLASS(spam)'] == 0)])}, {len(self.LD[(self.LD['i'] == 0) & (self.LD['CLASS(spam)'] == 1)])}")
        print(f"ft_ic['i'][1][0]:{self.ft_ic[col_to_idx['i']][1][0]}, ft_ic['i'][1][1]:{self.ft_ic[col_to_idx['i']][1][1]}")
        print(f"true : {len(self.LD[(self.LD['i'] == 1) & (self.LD['CLASS(spam)'] == 0)])}, {len(self.LD[(self.LD['i'] == 1) & (self.LD['CLASS(spam)'] == 1)])}")
        print("="*50)
        print(f"ft_ic['to'][0][0]:{self.ft_ic[col_to_idx['to']][0][0]}, ft_ic['to'][0][1]:{self.ft_ic[col_to_idx['to']][0][1]}")
        print(f"true : {len(self.LD[(self.LD['to'] == 0) & (self.LD['CLASS(spam)'] == 0)])}, {len(self.LD[(self.LD['to'] == 0) & (self.LD['CLASS(spam)'] == 1)])}")
        print(f"ft_ic['to'][1][0]:{self.ft_ic[col_to_idx['to']][1][0]}, ft_ic['to'][1][1]:{self.ft_ic[col_to_idx['to']][1][1]}")
        print(f"true : {len(self.LD[(self.LD['to'] == 1) & (self.LD['CLASS(spam)'] == 0)])}, {len(self.LD[(self.LD['to'] == 1) & (self.LD['CLASS(spam)'] == 1)])}")
        print("="*50)
        self.theta_k, self.theta_kc = self._get_parameters()
        print("Parameters have been set.")
        self.classification(self.theta_k, self.theta_kc)
    def _get_parameters(self):
        """
        変数自身とその親の値を鍵としてその条件付き確率パラメータを返すようなHashMapを、 各変数ごとにArrayListで繋いだものを返す関数
        """
        theta_k = [{} for _ in range(self.NC)]
        for i in range(self.NC):
            theta_k[i] = self.ft_c[i] / self.N
        theta_kc = [[[0 for _ in range(self.NC)] for _ in range(self.NC)]for _ in range(self.NV - 1)]
        for j in range(self.NV - 1):
            for k in range(self.NC):
                for c in range(self.NC):
                    if self.ft_c[c] == 0 or self.ft_ic[j][k][c] == 0:
                        theta_kc[j][k][c] = 1.0
                    else:
                        theta_kc[j][k][c] = self.ft_ic[j][k][c] / self.ft_c[c]

        return theta_k, theta_kc

    def classification(self,theta_k,theta_kc) -> None:
        num_correct_prediction = 0
        for i in range(len(self.TD)):
            print(f"Predicting Test Data {i+1}/{len(self.TD)}")
            # 真のクラスラベル
            y_true = self.TD.iat[i, self.NV - 1]
            prob_true = theta_k[1]
            prob_false = theta_k[0]
            for j in range(self.NV - 1):
                x_ij = self.TD.iat[i, j]
                prob_true *= theta_kc[j][x_ij][1]
                prob_false *= theta_kc[j][x_ij][0]
            y_pred = 1 if prob_true > prob_false else 0
            if y_true == y_pred:
                num_correct_prediction += 1
        # Print accuracy
        accuracy = (
            (num_correct_prediction / float(len(self.TD))) if len(self.TD) > 0 else 0.0
        )
        print(f"Classification accuracy: {accuracy}")
    def readData(self, filePath: str) -> None:
        self.LD = pd.read_csv(os.path.join(filePath, "LD.csv"))
        self.TD = pd.read_csv(os.path.join(filePath, "TD.csv"))
        self.NV = len(self.LD.columns)
        self.N = len(self.LD)

    def setFrequencyTable(self) -> None:
        """
        N_{X_0=c}とN_{X_i=k,X_0=c}をそれぞれft_c, ft_icに格納する関数
        """
        for j in range(self.NV - 1):
            for i in range(len(self.LD)):
                self.ft_ic[j][self.LD.iat[i, j]][self.LD.iat[i, self.NV - 1]] += 1
        for i in range(len(self.LD)):
            self.ft_c[self.LD.iat[i, self.NV - 1]] += 1

NB()
# Out:
# Dataset: spam
# Number of Test Data: 375
# Number of Learning Data: 1000
# Number of Variables: 301
# Frequency Table has been set.
# ==================================================
# ft_c[0]:451, ft_c[1]:549
# true : 451, 549
# ==================================================
# ft_ic['i'][0][0]:272, ft_ic['i'][0][1]:521
# true : 272, 521
# ft_ic['i'][1][0]:179, ft_ic['i'][1][1]:28
# true : 179, 28
# ==================================================
# ft_ic['to'][0][0]:348, ft_ic['to'][0][1]:199
# true : 348, 199
# ft_ic['to'][1][0]:103, ft_ic['to'][1][1]:350
# true : 103, 350
# ==================================================
# Parameters have been set.
# Predicting Test Data 1/375
# Predicting Test Data 2/375
# Predicting Test Data 3/375
# Predicting Test Data 4/375
# Predicting Test Data 5/375
# Predicting Test Data 6/375
# Predicting Test Data 7/375
# Predicting Test Data 8/375
# Predicting Test Data 9/375
# Predicting Test Data 10/375
# Predicting Test Data 11/375
# Predicting Test Data 12/375
# Predicting Test Data 13/375
# Predicting Test Data 14/375
# Predicting Test Data 15/375
# Predicting Test Data 16/375
# Predicting Test Data 17/375
# Predicting Test Data 18/375
# Predicting Test Data 19/375
# Predicting Test Data 20/375
# Predicting Test Data 21/375
# Predicting Test Data 22/375
# Predicting Test Data 23/375
# Predicting Test Data 24/375
# Predicting Test Data 25/375
# Predicting Test Data 26/375
# Predicting Test Data 27/375
# Predicting Test Data 28/375
# Predicting Test Data 29/375
# Predicting Test Data 30/375
# Predicting Test Data 31/375
# Predicting Test Data 32/375
# Predicting Test Data 33/375
# Predicting Test Data 34/375
# Predicting Test Data 35/375
# Predicting Test Data 36/375
# Predicting Test Data 37/375
# Predicting Test Data 38/375
# Predicting Test Data 39/375
# Predicting Test Data 40/375
# Predicting Test Data 41/375
# Predicting Test Data 42/375
# Predicting Test Data 43/375
# Predicting Test Data 44/375
# Predicting Test Data 45/375
# Predicting Test Data 46/375
# Predicting Test Data 47/375
# Predicting Test Data 48/375
# Predicting Test Data 49/375
# Predicting Test Data 50/375
# Predicting Test Data 51/375
# Predicting Test Data 52/375
# Predicting Test Data 53/375
# Predicting Test Data 54/375
# Predicting Test Data 55/375
# Predicting Test Data 56/375
# Predicting Test Data 57/375
# Predicting Test Data 58/375
# Predicting Test Data 59/375
# Predicting Test Data 60/375
# Predicting Test Data 61/375
# Predicting Test Data 62/375
# Predicting Test Data 63/375
# Predicting Test Data 64/375
# Predicting Test Data 65/375
# Predicting Test Data 66/375
# Predicting Test Data 67/375
# Predicting Test Data 68/375
# Predicting Test Data 69/375
# Predicting Test Data 70/375
# Predicting Test Data 71/375
# Predicting Test Data 72/375
# Predicting Test Data 73/375
# Predicting Test Data 74/375
# Predicting Test Data 75/375
# Predicting Test Data 76/375
# Predicting Test Data 77/375
# Predicting Test Data 78/375
# Predicting Test Data 79/375
# Predicting Test Data 80/375
# Predicting Test Data 81/375
# Predicting Test Data 82/375
# Predicting Test Data 83/375
# Predicting Test Data 84/375
# Predicting Test Data 85/375
# Predicting Test Data 86/375
# Predicting Test Data 87/375
# Predicting Test Data 88/375
# Predicting Test Data 89/375
# Predicting Test Data 90/375
# Predicting Test Data 91/375
# Predicting Test Data 92/375
# Predicting Test Data 93/375
# Predicting Test Data 94/375
# Predicting Test Data 95/375
# Predicting Test Data 96/375
# Predicting Test Data 97/375
# Predicting Test Data 98/375
# Predicting Test Data 99/375
# Predicting Test Data 100/375
# Predicting Test Data 101/375
# Predicting Test Data 102/375
# Predicting Test Data 103/375
# Predicting Test Data 104/375
# Predicting Test Data 105/375
# Predicting Test Data 106/375
# Predicting Test Data 107/375
# Predicting Test Data 108/375
# Predicting Test Data 109/375
# Predicting Test Data 110/375
# Predicting Test Data 111/375
# Predicting Test Data 112/375
# Predicting Test Data 113/375
# Predicting Test Data 114/375
# Predicting Test Data 115/375
# Predicting Test Data 116/375
# Predicting Test Data 117/375
# Predicting Test Data 118/375
# Predicting Test Data 119/375
# Predicting Test Data 120/375
# Predicting Test Data 121/375
# Predicting Test Data 122/375
# Predicting Test Data 123/375
# Predicting Test Data 124/375
# Predicting Test Data 125/375
# Predicting Test Data 126/375
# Predicting Test Data 127/375
# Predicting Test Data 128/375
# Predicting Test Data 129/375
# Predicting Test Data 130/375
# Predicting Test Data 131/375
# Predicting Test Data 132/375
# Predicting Test Data 133/375
# Predicting Test Data 134/375
# Predicting Test Data 135/375
# Predicting Test Data 136/375
# Predicting Test Data 137/375
# Predicting Test Data 138/375
# Predicting Test Data 139/375
# Predicting Test Data 140/375
# Predicting Test Data 141/375
# Predicting Test Data 142/375
# Predicting Test Data 143/375
# Predicting Test Data 144/375
# Predicting Test Data 145/375
# Predicting Test Data 146/375
# Predicting Test Data 147/375
# Predicting Test Data 148/375
# Predicting Test Data 149/375
# Predicting Test Data 150/375
# Predicting Test Data 151/375
# Predicting Test Data 152/375
# Predicting Test Data 153/375
# Predicting Test Data 154/375
# Predicting Test Data 155/375
# Predicting Test Data 156/375
# Predicting Test Data 157/375
# Predicting Test Data 158/375
# Predicting Test Data 159/375
# Predicting Test Data 160/375
# Predicting Test Data 161/375
# Predicting Test Data 162/375
# Predicting Test Data 163/375
# Predicting Test Data 164/375
# Predicting Test Data 165/375
# Predicting Test Data 166/375
# Predicting Test Data 167/375
# Predicting Test Data 168/375
# Predicting Test Data 169/375
# Predicting Test Data 170/375
# Predicting Test Data 171/375
# Predicting Test Data 172/375
# Predicting Test Data 173/375
# Predicting Test Data 174/375
# Predicting Test Data 175/375
# Predicting Test Data 176/375
# Predicting Test Data 177/375
# Predicting Test Data 178/375
# Predicting Test Data 179/375
# Predicting Test Data 180/375
# Predicting Test Data 181/375
# Predicting Test Data 182/375
# Predicting Test Data 183/375
# Predicting Test Data 184/375
# Predicting Test Data 185/375
# Predicting Test Data 186/375
# Predicting Test Data 187/375
# Predicting Test Data 188/375
# Predicting Test Data 189/375
# Predicting Test Data 190/375
# Predicting Test Data 191/375
# Predicting Test Data 192/375
# Predicting Test Data 193/375
# Predicting Test Data 194/375
# Predicting Test Data 195/375
# Predicting Test Data 196/375
# Predicting Test Data 197/375
# Predicting Test Data 198/375
# Predicting Test Data 199/375
# Predicting Test Data 200/375
# Predicting Test Data 201/375
# Predicting Test Data 202/375
# Predicting Test Data 203/375
# Predicting Test Data 204/375
# Predicting Test Data 205/375
# Predicting Test Data 206/375
# Predicting Test Data 207/375
# Predicting Test Data 208/375
# Predicting Test Data 209/375
# Predicting Test Data 210/375
# Predicting Test Data 211/375
# Predicting Test Data 212/375
# Predicting Test Data 213/375
# Predicting Test Data 214/375
# Predicting Test Data 215/375
# Predicting Test Data 216/375
# Predicting Test Data 217/375
# Predicting Test Data 218/375
# Predicting Test Data 219/375
# Predicting Test Data 220/375
# Predicting Test Data 221/375
# Predicting Test Data 222/375
# Predicting Test Data 223/375
# Predicting Test Data 224/375
# Predicting Test Data 225/375
# Predicting Test Data 226/375
# Predicting Test Data 227/375
# Predicting Test Data 228/375
# Predicting Test Data 229/375
# Predicting Test Data 230/375
# Predicting Test Data 231/375
# Predicting Test Data 232/375
# Predicting Test Data 233/375
# Predicting Test Data 234/375
# Predicting Test Data 235/375
# Predicting Test Data 236/375
# Predicting Test Data 237/375
# Predicting Test Data 238/375
# Predicting Test Data 239/375
# Predicting Test Data 240/375
# Predicting Test Data 241/375
# Predicting Test Data 242/375
# Predicting Test Data 243/375
# Predicting Test Data 244/375
# Predicting Test Data 245/375
# Predicting Test Data 246/375
# Predicting Test Data 247/375
# Predicting Test Data 248/375
# Predicting Test Data 249/375
# Predicting Test Data 250/375
# Predicting Test Data 251/375
# Predicting Test Data 252/375
# Predicting Test Data 253/375
# Predicting Test Data 254/375
# Predicting Test Data 255/375
# Predicting Test Data 256/375
# Predicting Test Data 257/375
# Predicting Test Data 258/375
# Predicting Test Data 259/375
# Predicting Test Data 260/375
# Predicting Test Data 261/375
# Predicting Test Data 262/375
# Predicting Test Data 263/375
# Predicting Test Data 264/375
# Predicting Test Data 265/375
# Predicting Test Data 266/375
# Predicting Test Data 267/375
# Predicting Test Data 268/375
# Predicting Test Data 269/375
# Predicting Test Data 270/375
# Predicting Test Data 271/375
# Predicting Test Data 272/375
# Predicting Test Data 273/375
# Predicting Test Data 274/375
# Predicting Test Data 275/375
# Predicting Test Data 276/375
# Predicting Test Data 277/375
# Predicting Test Data 278/375
# Predicting Test Data 279/375
# Predicting Test Data 280/375
# Predicting Test Data 281/375
# Predicting Test Data 282/375
# Predicting Test Data 283/375
# Predicting Test Data 284/375
# Predicting Test Data 285/375
# Predicting Test Data 286/375
# Predicting Test Data 287/375
# Predicting Test Data 288/375
# Predicting Test Data 289/375
# Predicting Test Data 290/375
# Predicting Test Data 291/375
# Predicting Test Data 292/375
# Predicting Test Data 293/375
# Predicting Test Data 294/375
# Predicting Test Data 295/375
# Predicting Test Data 296/375
# Predicting Test Data 297/375
# Predicting Test Data 298/375
# Predicting Test Data 299/375
# Predicting Test Data 300/375
# Predicting Test Data 301/375
# Predicting Test Data 302/375
# Predicting Test Data 303/375
# Predicting Test Data 304/375
# Predicting Test Data 305/375
# Predicting Test Data 306/375
# Predicting Test Data 307/375
# Predicting Test Data 308/375
# Predicting Test Data 309/375
# Predicting Test Data 310/375
# Predicting Test Data 311/375
# Predicting Test Data 312/375
# Predicting Test Data 313/375
# Predicting Test Data 314/375
# Predicting Test Data 315/375
# Predicting Test Data 316/375
# Predicting Test Data 317/375
# Predicting Test Data 318/375
# Predicting Test Data 319/375
# Predicting Test Data 320/375
# Predicting Test Data 321/375
# Predicting Test Data 322/375
# Predicting Test Data 323/375
# Predicting Test Data 324/375
# Predicting Test Data 325/375
# Predicting Test Data 326/375
# Predicting Test Data 327/375
# Predicting Test Data 328/375
# Predicting Test Data 329/375
# Predicting Test Data 330/375
# Predicting Test Data 331/375
# Predicting Test Data 332/375
# Predicting Test Data 333/375
# Predicting Test Data 334/375
# Predicting Test Data 335/375
# Predicting Test Data 336/375
# Predicting Test Data 337/375
# Predicting Test Data 338/375
# Predicting Test Data 339/375
# Predicting Test Data 340/375
# Predicting Test Data 341/375
# Predicting Test Data 342/375
# Predicting Test Data 343/375
# Predicting Test Data 344/375
# Predicting Test Data 345/375
# Predicting Test Data 346/375
# Predicting Test Data 347/375
# Predicting Test Data 348/375
# Predicting Test Data 349/375
# Predicting Test Data 350/375
# Predicting Test Data 351/375
# Predicting Test Data 352/375
# Predicting Test Data 353/375
# Predicting Test Data 354/375
# Predicting Test Data 355/375
# Predicting Test Data 356/375
# Predicting Test Data 357/375
# Predicting Test Data 358/375
# Predicting Test Data 359/375
# Predicting Test Data 360/375
# Predicting Test Data 361/375
# Predicting Test Data 362/375
# Predicting Test Data 363/375
# Predicting Test Data 364/375
# Predicting Test Data 365/375
# Predicting Test Data 366/375
# Predicting Test Data 367/375
# Predicting Test Data 368/375
# Predicting Test Data 369/375
# Predicting Test Data 370/375
# Predicting Test Data 371/375
# Predicting Test Data 372/375
# Predicting Test Data 373/375
# Predicting Test Data 374/375
# Predicting Test Data 375/375
# Classification accuracy: 0.8106666666666666
